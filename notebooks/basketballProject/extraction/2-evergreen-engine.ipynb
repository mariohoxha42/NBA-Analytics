# %%
# import python libraries and nba library
import pandas as np
import nba_api as nba
from matplotlib import pyplot as plt
import pandas as pd
import socket
import logging
import os
import glob

# %%
# import use-case specific 
from nba_api.stats.endpoints import leagueleaders

# %%
# extract league leaders from API 
leaders_df = leagueleaders.LeagueLeaders().get_data_frames()[0]

# %%
display(leaders_df)
# Out:
#      PLAYER_ID  RANK                   PLAYER     TEAM_ID TEAM  GP   MIN  FGM  \
# 0       201142     1             Kevin Durant  1610612751  BKN  31  1130  335
# 1      1629029     1              Luka Doncic  1610612742  DAL  29  1054  318
# 2      1628369     3             Jayson Tatum  1610612738  BOS  30  1115  301
# 3      1628983     4  Shai Gilgeous-Alexander  1610612760  OKC  29  1034  299
# 4      1628378     5         Donovan Mitchell  1610612739  CLE  29  1056  298
# ..         ...   ...                      ...         ...  ...  ..   ...  ...
# 484    1630250   477          Marko Simonovic  1610612741  CHI   1     2    0
# 485    1630701   477       Michael Foster Jr.  1610612755  PHI   1     1    0
# 486    1630243   477           Trevelin Queen  1610612754  IND   2    20    0
# 487    1631211   477             Trevor Keels  1610612752  NYK   1     1    0
# 488    1630176   477         Vernon Carey Jr.  1610612764  WAS   3     5    0
#
#      FGA  FG_PCT  ...  REB  AST  STL  BLK  TOV  PF  PTS  EFF  AST_TOV  STL_TOV
# 0    594   0.564  ...  205  163   26   49  109  73  934  992     1.50     0.24
# 1    644   0.494  ...  240  251   47   17  106  81  934  980     2.37     0.44
# 2    638   0.472  ...  243  122   34   28   82  63  917  890     1.49     0.41
# 3    600   0.498  ...  135  166   49   29   99  75  904  862     1.68     0.49
# 4    592   0.503  ...  110  130   39   10   85  77  855  748     1.53     0.46
# ..   ...     ...  ...  ...  ...  ...  ...  ...  ..  ...  ...      ...      ...
# 484    1   0.000  ...    0    0    0    0    0   0    0   -1     0.00     0.00
# 485    0   0.000  ...    0    0    0    0    0   0    0    0     0.00     0.00
# 486    3   0.000  ...    3    2    1    1    3   1    0    1     0.67     0.33
# 487    1   0.000  ...    1    0    0    0    0   0    0    0     0.00     0.00
# 488    2   0.000  ...    1    0    0    0    1   2    0   -2     0.00     0.00
#
# [489 rows x 28 columns]

# %%
# write file to repo location
file_path = "C:/Github Repo/NBA-Analytics/data/basketballProject/evergreen-files/"
# file_path = "../../data/basketballProject/evergreen-files/"
file_name = "league_leaders"
file_extension = ".csv"
full_path = file_path + file_name + file_extension
leaders_df.to_csv(full_path)
