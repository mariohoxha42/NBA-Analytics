# %%
import logging

# %%
logging.info("initiating orchestration...")

# %%
# %run "C:/Github Repo/NBA-Analytics/notebooks/basketballProject/extraction/2-evergreen-engine.ipynb"

# %%
logging.info("successful evergreen run!")

# %%
# %run "C:/Github Repo/NBA-Analytics/notebooks/basketballProject/extraction/3-consolidation-engine.ipynb"

# %%
logging.info("successful update of consolidated stats!")

# %%
# %run "C:/Github Repo/NBA-Analytics/notebooks/basketballProject/processing/1-cleansing-engine.ipynb"
# Out:
#       Season #              PLAYER     TEAM_ID   SEASON_ID TEAM    GP  Age  \
# 0            0        Nerlens Noel     2014-15  1610612755  PHI  21.0   75
# 1            1        Nerlens Noel     2015-16  1610612755  PHI  22.0   67
# 2            2        Nerlens Noel     2016-17  1610612755  PHI  23.0   29
# 3            3        Nerlens Noel     2016-17  1610612742  DAL  23.0   22
# 4            4        Nerlens Noel     2016-17           0  TOT  23.0   51
# ...        ...                 ...         ...         ...  ...   ...  ...
# 3319        -1     Marko Simonovic  1610612741     2022-23  CHI   1.0    0
# 3320        -1  Michael Foster Jr.  1610612755     2022-23  PHI   1.0    0
# 3321        -1      Trevelin Queen  1610612754     2022-23  IND   2.0    0
# 3322        -1        Trevor Keels  1610612752     2022-23  NYK   1.0    0
# 3323        -1    Vernon Carey Jr.  1610612764     2022-23  WAS   3.0    0
#
#          MIN  FGM  FGA  ...  TOV   PF  PTS    MOWAR  MDWAR  MPWAR   MIWAR  \
# 0     2311.0  302  653  ...  146  208  744  1263.75  446.0    -54  3340.0
# 1     1965.0  306  587  ...  158  192  747  1183.20  340.0   -108  2807.0
# 2      564.0  107  175  ...   29   71  257   361.25  102.5      3   484.0
# 3      483.0   77  134  ...   22   55  188   271.85   64.5     -6   416.0
# 4     1047.0  184  309  ...   51  126  445   633.10  167.0     -3  1314.0
# ...      ...  ...  ...  ...  ...  ...  ...      ...    ...    ...     ...
# 3319     2.0    0    1  ...    0    0    0     2.50    0.0      0   -16.0
# 3320     1.0    0    0  ...    0    0    0     0.00    0.0      0   -17.0
# 3321    20.0    0    3  ...    3    1    0     7.50    3.5     -3    -9.0
# 3322     1.0    0    1  ...    0    0    0     2.50    0.0      0   -15.0
# 3323     5.0    0    2  ...    1    2    0     2.50   -1.0     -3   -47.0
#
#          MWAR     MWARPM      MWARPG
# 0     4995.75   2.161727  237.892857
# 1     4222.20   2.148702  191.918182
# 2      950.75   1.685727   41.336957
# 3      746.35   1.545238   32.450000
# 4     2111.10   2.016332   91.786957
# ...       ...        ...         ...
# 3319   -13.50  -6.750000  -13.500000
# 3320   -17.00 -17.000000  -17.000000
# 3321    -1.00  -0.050000   -0.500000
# 3322   -12.50 -12.500000  -12.500000
# 3323   -48.50  -9.700000  -16.166667
#
# [3324 rows x 33 columns]

# %%
logging.info("successful cleaning of data!")
